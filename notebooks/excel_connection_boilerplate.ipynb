# %%
from cinofinance.dividend import Dividend

# %%
Dividend().get_portfolio()
# Out:
#          Sep 22  Okt 22 Nov 22 Dez 22 Jan 23 Feb 23 Mrz 23 Apr 23 Mai 23  \
# Tickers
# AGNC         25      29   None   None   None   None   None   None   None
# BNTX          1       1   None   None   None   None   None   None   None
# MCO           1       1   None   None   None   None   None   None   None
# MSFT          1       1   None   None   None   None   None   None   None
# NVDA          2       2   None   None   None   None   None   None   None
# ORC           7      15   None   None   None   None   None   None   None
# STAG         11      11   None   None   None   None   None   None   None
# V             1       1   None   None   None   None   None   None   None
#
#         Jun 23 Jul 23 Aug 23 Sep 23 Okt 23 Nov 23 Dez 23 Jan 24 Feb 24
# Tickers
# AGNC      None   None   None   None   None   None   None   None   None
# BNTX      None   None   None   None   None   None   None   None   None
# MCO       None   None   None   None   None   None   None   None   None
# MSFT      None   None   None   None   None   None   None   None   None
# NVDA      None   None   None   None   None   None   None   None   None
# ORC       None   None   None   None   None   None   None   None   None
# STAG      None   None   None   None   None   None   None   None   None
# V         None   None   None   None   None   None   None   None   None

# %%
# Out:
# Tickers
# AGNC    29
# BNTX     1
# MCO      1
# MSFT     1
# NVDA     2
# ORC     15
# STAG    11
# V        1
# Name: Okt 22, dtype: int64

# %%
portfolio = Dividend().get_portfolio()['Okt 22']

# %%
df = Dividend().get_portfolio_dividends(portfolio)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lot'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3473/1546811752.py in <module>
# ----> 1 df = Dividend().get_portfolio_dividends(portfolio)
#       2 df
#
# ~/code/SinanSeyhan/cinofinance/cinofinance/dividend.py in get_portfolio_dividends(self, portfolio)
#     144
#     145         # Multiplying the Lot Size
# --> 146         df[month_columns] = df[month_columns].multiply(df['Lot'], axis='index')
#     147         df['Dividend, annual'] = df[month_columns].sum(axis=1)
#     148
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Lot'
