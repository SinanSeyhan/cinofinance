# %%
# %load_ext autoreload
# %autoreload 2
from cinofinance.portfolio import Portfolio
# Out:
# /home/sinan/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (5.0.0)/charset_normalizer (2.0.10) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
portfolio = Portfolio().get_portfolio()
portfolio
# Out:
#                                             Name        Country  \
# Tickers
# AGNC          AGNC Investment Corp. Common Stock  United States
# BNTX       BioNTech SE American Depositary Share        Germany
# MCO             Moody's Corporation Common Stock  United States
# MSFT          Microsoft Corporation Common Stock  United States
# NVDA             NVIDIA Corporation Common Stock  United States
# ORC      Orchid Island Capital Inc. Common Stock  United States
# STAG           Stag Industrial Inc. Common Stock  United States
# V                                      Visa Inc.  United States
# INTC              Intel Corporation Common Stock  United States
# KO          Coca-Cola Company (The) Common Stock  United States
#
#                          Sector  \
# Tickers
# AGNC                Real Estate
# BNTX                Health Care
# MCO                     Finance
# MSFT                 Technology
# NVDA                 Technology
# ORC                 Real Estate
# STAG                Real Estate
# V        Consumer Discretionary
# INTC                 Technology
# KO             Consumer Staples
#
#                                                   Industry  2022-08  2022-09  \
# Tickers
# AGNC                         Real Estate Investment Trusts       25       29
# BNTX     Biotechnology: Biological Products (No Diagnos...        1        1
# MCO                                            Advertising        1        1
# MSFT               Computer Software: Prepackaged Software        1        1
# NVDA                                        Semiconductors        2        2
# ORC                          Real Estate Investment Trusts        7       15
# STAG                         Real Estate Investment Trusts       11       11
# V                                        Business Services        1        1
# INTC                                        Semiconductors        0        0
# KO                     Beverages (Production/Distribution)        0        0
#
#          2022-10
# Tickers
# AGNC          55
# BNTX           1
# MCO            1
# MSFT           1
# NVDA           2
# ORC           50
# STAG          11
# V              1
# INTC           8
# KO             4

# %%
dividends = Portfolio().get_portfolio_dividend()
dividends
# Out:
# [*********************100%***********************]  10 of 10 completed
#          2022-08  2022-09  2022-10                                     Name
# Tickers
# AGNC       3.000    3.480    6.600       AGNC Investment Corp. Common Stock
# BNTX       0.000    0.000    0.000    BioNTech SE American Depositary Share
# MCO        0.000    0.700    0.000         Moody's Corporation Common Stock
# MSFT       0.000    0.620    0.000       Microsoft Corporation Common Stock
# NVDA       0.000    0.080    0.000          NVIDIA Corporation Common Stock
# ORC        1.575    2.400    8.000  Orchid Island Capital Inc. Common Stock
# STAG       1.342    1.342    1.342        Stag Industrial Inc. Common Stock
# V          0.375    0.000    0.000                                Visa Inc.
# INTC       0.000    0.000    0.000           Intel Corporation Common Stock
# KO         0.000    0.000    0.000     Coca-Cola Company (The) Common Stock

# %%
result = portfolio.mul(dividends).dropna(axis=1)
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: can't multiply sequence by non-int of type 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1039/2701586009.py in <module>
# ----> 1 result = portfolio.mul(dividends).dropna(axis=1)
#       2 result
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     421             self, other, op, axis, default_axis, fill_value, level
#     422         ):
# --> 423             return frame_arith_method_with_reindex(self, other, op)
#     424
#     425         if isinstance(other, ABCSeries) and fill_value is not None:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/ops/__init__.py in frame_arith_method_with_reindex(left, right, op)
#     363     new_left = left.iloc[:, lcols]
#     364     new_right = right.iloc[:, rcols]
# --> 365     result = op(new_left, new_right)
#     366
#     367     # Do the join on the columns instead of using align_method_FRAME
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/arraylike.py in __mul__(self, other)
#     106     @unpack_zerodim_and_defer("__mul__")
#     107     def __mul__(self, other):
# --> 108         return self._arith_method(other, operator.mul)
#     109
#     110     @unpack_zerodim_and_defer("__rmul__")
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# -> 6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867         return self._construct_result(new_data)
#    6868
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    6903             # TODO operate_blockwise expects a manager of the same type
#    6904             with np.errstate(all="ignore"):
# -> 6905                 bm = self._mgr.operate_blockwise(
#    6906                     # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    6907                     # incompatible type "Union[ArrayManager, BlockManager]"; expected
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/internals/managers.py in operate_blockwise(self, other, array_op)
#    1301         Apply array_op blockwise with another (aligned) BlockManager.
#    1302         """
# -> 1303         return operate_blockwise(self, other, array_op)
#    1304
#    1305     def _equal_values(self: BlockManager, other: BlockManager) -> bool:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/internals/ops.py in operate_blockwise(left, right, array_op)
#      55     res_blks: list[Block] = []
#      56     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 57         res_values = array_op(lvals, rvals)
#      58         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      59             res_values = res_values.reshape(1, -1)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     171             # Don't do this for comparisons, as that will handle complex numbers
#     172             #  incorrectly, see GH#32047
# --> 173             result = _masked_arith_op(left, right, op)
#     174         else:
#     175             raise
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     110         # See GH#5284, GH#5035, GH#19448 for historical reference
#     111         if mask.any():
# --> 112             result[mask] = op(xrav[mask], yrav[mask])
#     113
#     114     else:
#
# TypeError: can't multiply sequence by non-int of type 'str'
